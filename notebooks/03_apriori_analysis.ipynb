# %%
import sys
import os

project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
if project_root not in sys.path:
    sys.path.append(project_root)

# %%
from src.data_cleaning import load_and_clean_data
from src.transaction_encoder import create_basket, one_hot_encode
from src.apriori_analysis import run_apriori

# %%
data_path = os.path.join(project_root, "data", "Online_Retail.csv")

df = load_and_clean_data(data_path)
basket = create_basket(df)
basket = basket[basket.apply(len) > 1]
encoded_df = one_hot_encode(basket)

# %%
frequent_itemsets = run_apriori(encoded_df, min_support=0.02)
frequent_itemsets.head()
# Out:
#     support                              itemsets  itemset_size
# 0  0.122112  (white hanging heart t-light holder)             1
# 1  0.113230             (jumbo bag red retrospot)             1
# 2  0.107182            (regency cakestand 3 tier)             1
# 3  0.091053                       (party bunting)             1
# 4  0.085168             (lunch bag red retrospot)             1

# %%
frequent_itemsets['itemset_size'].value_counts()
# Out:
# itemset_size
# 1    345
# 2    106
# 3      5
# Name: count, dtype: int64

# %%
frequent_itemsets.head(10)
# Out:
#     support                              itemsets  itemset_size
# 0  0.122112  (white hanging heart t-light holder)             1
# 1  0.113230             (jumbo bag red retrospot)             1
# 2  0.107182            (regency cakestand 3 tier)             1
# 3  0.091053                       (party bunting)             1
# 4  0.085168             (lunch bag red retrospot)             1
# 5  0.079174       (assorted colour bird ornament)             1
# 6  0.074978    (set of 3 cake tins pantry design)             1
# 7  0.071927     (pack of 72 retrospot cake cases)             1
# 8  0.069257             (lunch bag  black skull.)             1
# 9  0.068003      (natural slate heart chalkboard)             1
